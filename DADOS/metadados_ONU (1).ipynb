# %%
# Configuração de Caminhos (Portabilidade)

import os

IS_COLAB = 'google.colab' in str(get_ipython())
if IS_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    BASE_PATH = '/content/drive/MyDrive/metadados_projeto/dados/' # Ajuste para o seu caminho
else:
    BASE_PATH = 'dados/'

print(f"Ambiente configurado. Buscando dados em: {BASE_PATH}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Ambiente configurado. Buscando dados em: /content/drive/MyDrive/metadados_projeto/dados/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Usando a variável BASE_PATH
caminho_onu = f"{BASE_PATH}dataset.txt"

# Lendo a base de dados da ONU com o separador ponto e vírgula
dados_onu = pd.read_csv(caminho_onu, sep=';') #

# Exibindo as 5 primeiras linhas para conferir a importação
dados_onu.head() #
# Out:
#   Country or territory of asylum or residence Country or territory of origin  \
# 0                                 Afghanistan         Iran (Islamic Rep. of)
# 1                                 Afghanistan                       Pakistan
# 2                                     Albania                          China
# 3                                     Albania                          Egypt
# 4                                     Albania                           Iraq
#
#      Year  Refugees*  Refugees assisted by UNHCR  \
# 0  2021.0       38.0                        38.0
# 1  2021.0    72188.0                       123.0
# 2  2021.0       14.0                         0.0
# 3  2021.0        5.0                         0.0
# 4  2021.0        5.0                         0.0
#
#    Total refugees and people in refugee-like situations**  \
# 0                                               38.0
# 1                                            72188.0
# ...

# %%
import pandas as pd

# Criando o dataframe que será o nosso repositório central
metadados = pd.DataFrame() #

# %% [markdown]
# **Base da ONU (Refugiados)**

# %%
# Nome físico: o nome do arquivo que contém os dados
metadados['nome_fisico'] = ['dataset.txt'] #

# Nome lógico: tradução amigável para quem vai acessar
metadados['nome_logico'] = ['Dados sobre pessoas refugiadas'] #

# Descrição detalhada do contexto
metadados['descricao'] = ['Essa base possui informações sobre refugiados e pessoas em situação de refúgio coletadas pelo ACNUR, órgão da ONU especializado no tema'] #

# Palavras-chave para facilitar a busca
metadados['palavras_chave'] = ['Relações Internacionais, ONU, Refugiados, Direitos Humanos'] #

# Visualizando como ficou
metadados
# Out:
#    nome_fisico                     nome_logico  \
# 0  dataset.txt  Dados sobre pessoas refugiadas
#
#                                            descricao  \
# 0  Essa base possui informações sobre refugiados ...
#
#                                       palavras_chave
# 0  Relações Internacionais, ONU, Refugiados, Dire...

# %% [markdown]
# **Base da Liga Japonesa**

# %%
#  informações da segunda base
liga_japonesa = [
    'results.parquet',
    'Resultados da liga de futebol japonesa',
    'Essa base possui informações sobre resultados das partidas da liga japonesa de futebol masculino entre os anos de 2012 a 2022.',
    'Esportes, Liga Japonesa, Futebol, Resultados esportivos'
] #

# Inserindo os dados na linha 1
metadados.loc[1] = liga_japonesa #

# Conferindo
metadados
# Out:
#        nome_fisico                             nome_logico  \
# 0      dataset.txt          Dados sobre pessoas refugiadas
# 1  results.parquet  Resultados da liga de futebol japonesa
#
#                                            descricao  \
# 0  Essa base possui informações sobre refugiados ...
# 1  Essa base possui informações sobre resultados ...
#
#                                       palavras_chave
# 0  Relações Internacionais, ONU, Refugiados, Dire...
# 1  Esportes, Liga Japonesa, Futebol, Resultados e...

# %% [markdown]
# **Adicionando a Imagem**

# %%
#  metadados da imagem
foto_laboratorio = [
    '20240314_225158.jpg',
    'Fotografia do Laboratório',
    'Imagem em formato JPEG contendo metadados EXIF, capturada para testar a extração de informações de hardware (Samsung S23 Ultra) e localização.',
    'Imagem, Não Estruturado, Metadados EXIF, Laboratório'
]

# Inserindo os dados na linha 2 do nosso repositório mestre
metadados.loc[2] = foto_laboratorio

# Exibindo o repositório completo agora com 3 tipos de bases
metadados
# Out:
#            nome_fisico                             nome_logico  \
# 0          dataset.txt          Dados sobre pessoas refugiadas
# 1      results.parquet  Resultados da liga de futebol japonesa
# 2  20240314_225158.jpg               Fotografia do Laboratório
#
#                                            descricao  \
# 0  Essa base possui informações sobre refugiados ...
# 1  Essa base possui informações sobre resultados ...
# 2  Imagem em formato JPEG contendo metadados EXIF...
#
#                                       palavras_chave
# 0  Relações Internacionais, ONU, Refugiados, Dire...
# 1  Esportes, Liga Japonesa, Futebol, Resultados e...
# 2  Imagem, Não Estruturado, Metadados EXIF, Labor...

# %% [markdown]
# **Repositório Central**

# %%
import pandas as pd

# Criando o Repositório Central de Metadados
metadados = pd.DataFrame()

# Adicionando as bases de forma estruturada
dados_projeto = [
    ['dataset.txt', 'Dados sobre pessoas refugiadas', 'Informações coletadas pelo ACNUR/ONU sobre refugiados no mundo.', 'ONU, Refugiados, Direitos Humanos'],
    ['results.parquet', 'Resultados da liga de futebol japonesa', 'Resultados das partidas da liga J-League entre 2012 e 2022.', 'Esportes, Futebol, Japão'],
    ['20240314_225158.jpg', 'Fotografia do Laboratório', 'Imagem JPEG com metadados técnicos EXIF capturada para testes de hardware.', 'Imagem, Não Estruturado, EXIF']
]

metadados = pd.DataFrame(dados_projeto, columns=['nome_fisico', 'nome_logico', 'descricao', 'palavras_chave'])

# Exportando o Catálogo (Boa prática de Governança!)
metadados.to_csv('repositorio_metadados_master.csv', index=False)
metadados
# Out:
#            nome_fisico                             nome_logico  \
# 0          dataset.txt          Dados sobre pessoas refugiadas
# 1      results.parquet  Resultados da liga de futebol japonesa
# 2  20240314_225158.jpg               Fotografia do Laboratório
#
#                                            descricao  \
# 0  Informações coletadas pelo ACNUR/ONU sobre ref...
# 1  Resultados das partidas da liga J-League entre...
# 2  Imagem JPEG com metadados técnicos EXIF captur...
#
#                       palavras_chave
# 0  ONU, Refugiados, Direitos Humanos
# 1           Esportes, Futebol, Japão
# 2      Imagem, Não Estruturado, EXIF

# %% [markdown]
# **Metadado "Ativo"**

# %%
# Exemplo de Metadado Ativo: Análise Rápida de Qualidade
dados_onu = pd.read_csv(f'{BASE_PATH}dataset.txt', sep=';')

print("--- Diagnóstico de Qualidade de Dados ---")
total_nulos = dados_onu.isnull().sum().sum()
status = "⚠️ Atenção: Dados Ausentes" if total_nulos > 0 else "✅ Dados Completos"
print(f"Status da Base ONU: {status} ({total_nulos} valores nulos)")
# Out:
# --- Diagnóstico de Qualidade de Dados ---
# Status da Base ONU: ⚠️ Atenção: Dados Ausentes (15 valores nulos)
